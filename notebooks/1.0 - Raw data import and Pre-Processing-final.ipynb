# %% [markdown]
# # <center>Data Cleaning and Preparing Categorical- and Numerical Output Datasets</center> #

# %% [markdown]
# ### Step 1: Import libraries and load raw data ###

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
# %cd ..
# %cd data/raw
# Out:
# C:\Users\SiddharthaMisra\Documents\Springboard\AAQL_Analysis
# C:\Users\SiddharthaMisra\Documents\Springboard\AAQL_Analysis\data\raw

# %%
raw_data = pd.read_csv('Final Report_AAQL.csv')
raw_data.head()
# Out:
#    Survey ID   Age  Gender     Ethnicity Marital Status  Education Completed  \
# 0      80314   NaN     NaN    Vietnamese            NaN                  NaN
# 1      60171  60.0    Male       Chinese        Married                 13.0
# 2    1011601  23.0  Female       Chinese         Single                 16.0
# 3      50046  73.0  Female       Chinese          Other                 13.0
# 4      10494  29.0    Male  Asian Indian         Single                 17.0
#
#    Household Size              No One Spouse              Children  ...  \
# 0             NaN                 NaN    NaN                   NaN  ...
# 1             6.0                   0      0  Living with children  ...
# 2             3.0                   0      0                     0  ...
# 3             1.0  Living with no one      0                     0  ...
# 4             1.0  Living with no one      0                     0  ...
#
#   Other Description (Non-city-based Ethnic) Paper (Non-city-based General)  \
# 0                                       NaN                            NaN
# 1                                       NaN                            NaN
# 2                                       NaN                             No
# 3                                       NaN                            NaN
# 4                                       NaN                            NaN
#
#    TV/Radio (Non-city-based General) Website (Non-city-based General)  \
# 0                                NaN                              NaN
# 1                                NaN                              NaN
# 2                                 No                               No
# 3                                NaN                              NaN
# 4                                NaN                              NaN
#
#    Social Networks (Non-city-based General) People (Non-city-based General)  \
# 0                                       NaN                             NaN
# 1                                       NaN                             NaN
# 2                                        No                             Yes
# 3                                       NaN                             NaN
# 4                                       NaN                             NaN
#
#    Other (Non-city-based General) Other Description (Non-city-based General)  \
# 0                             NaN                                        NaN
# 1                             NaN                                        NaN
# 2                              No                                        NaN
# 3                             NaN                                        NaN
# 4                             NaN                                        NaN
#
#   Preferred Type Concerns
# 0            NaN      NaN
# 1            NaN      NaN
# 2          email  traffic
# 3            NaN      NaN
# 4            NaN      NaN
#
# [5 rows x 231 columns]

# %% [markdown]
# ### Step 2: Profile of raw data ###

# %%
from pandas_profiling import ProfileReport
report = ProfileReport(raw_data).to_file("Pandas Raw Data Profile.html")
# Out:
# C:\Users\SiddharthaMisra\Anaconda3\lib\site-packages\pandas_profiling\describe.py:392: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)

# %%
raw_data.shape
# Out:
# (2609, 231)

# %%
pd.set_option('display.max_rows',240,'display.max_columns',240)
raw_data.dtypes
# Out:
# Survey ID                                       int64
# Age                                           float64
# Gender                                         object
# Ethnicity                                      object
# Marital Status                                 object
# Education Completed                           float64
# Household Size                                float64
# No One                                         object
# Spouse                                         object
# Children                                       object
# Grand Children                                 object
# Parent                                         object
# Grandparent                                   float64
# Brother/Sister                                 object
# Other Relative                                float64
# Friends                                        object
# Other                                         float64
# Other Description                              object
# Religion                                       object
# Religion Other                                 object
# Full Time Employment                           object
# Part Time Employment                           object
# Self Employed Full Time                       float64
# Self Employed Part Time                       float64
# Student                                        object
# Homemaker                                      object
# Disabled                                      float64
# Unemployed                                    float64
# Retired                                        object
# Other Employement                             float64
# Other Employment Description                   object
# Occupation                                     object
# Occupation Other                               object
# Income                                         object
# Achieving Ends Meet                           float64
# US Born                                        object
# Duration of Residency                         float64
# Primary Language                              float64
# English Speaking                               object
# English Difficulties                           object
# Familiarity with America                       object
# Familiarity with Ethnic Origin                 object
# Identify Ethnically                            object
# Belonging                                      object
# Discrimination                                float64
# Present Health                                 object
# Present Mental Health                          object
# Present Oral Health                            object
# Hygiene Assistance                            float64
# Smoking                                       float64
# Drinking                                      float64
# Regular Exercise                              float64
# Healthy Diet                                  float64
# Hypertension                                   object
# Heart Disease                                 float64
# Stroke                                        float64
# Diabetes                                       object
# Cancer                                        float64
# Arthritis                                      object
# Hepatitis                                     float64
# Kidney Problem                                float64
# Asthma                                        float64
# COPD                                          float64
# Physical Check-up                              object
# Dentist Check-up                               object
# Urgentcare                                     object
# Folkmedicine                                   object
# Primary Care                                   object
# Health Insurance                               object
# Dental Insurance                               object
# Unmet Health Need                              object
# Unmet Dental Needs                             object
# Transportation (Medical)                       object
# Interpretation (Medical)                       object
# Comunication Problem                           object
# Preferance                                     object
# Language                                       object
# users                                         float64
# Satisfaction                                   object
# Family                                         object
# Close Friend                                   object
# Acquaintances                                  object
# Heal Professionals                             object
# Mobile Apps                                    object
# Email                                          object
# Social Networks                                object
# Online Communities                             object
# Health Website                                 object
# Other                                         float64
# Health Info Discription                        object
# Quality of Life                               float64
# Satisfied With Life 1                          object
# Satisfied With Life 2                          object
# Psychiatrist                                  float64
# General Practitioner                           object
# Therapist/Counselor                           float64
# Religious Leader                               object
# Weakness                                       object
# Shame                                          object
# Disappointment                                 object
# Disclosure                                     object
# Antidepressants                                object
# Danger                                         object
# Recovery                                       object
# Treatment                                      object
# Counseling                                     object
# Preference                                     object
# Knowledge                                      object
# Diagnosed                                      object
# Concern for Self (AD)                          object
# Concern for Others (AD)                        object
# Prevention                                     object
# Plan (AD)                                      object
# Education (AD)                                 object
# Services (AD)                                  object
# Language Barrier (AD)                          object
# Fate (AD)                                      object
# Aging (AD)                                     object
# Embarrassing (AD)                              object
# Avoidance (AD)                                 object
# Cure (AD)                                      object
# Nursing Home (AD)                              object
# Advanced Directives                            object
# Have an Advanced Directive                     object
# Superstition                                   object
# See Family                                    float64
# Close Family                                  float64
# Helpful Family                                float64
# See Friends                                   float64
# Close Friends                                 float64
# Helpful Friends                               float64
# Family Respect                                 object
# Similar Values                                 object
# Successful Family                              object
# Trust                                          object
# Loyalty                                        object
# Family Pride                                   object
# Expression                                     object
# Spend Time Together                            object
# Feel Close                                     object
# Togetherness                                   object
# Religious Attendance                           object
# Religious Importance                           object
# Close-knit Community                           object
# Helpful Community                              object
# Community Shares Values                        object
# Get Along                                      object
# Community Trust                                object
# Residency                                     float64
# Place to Live                                  object
# Raising Children                               object
# Place to Work                                  object
# Small Businesses                               object
# Place to Retire                                object
# Arts and Culture                               object
# Safety                                         object
# Traffic                                        object
# Qualtiy of Life                                object
# Quality of Service                             object
# Parks and Recs                                 object
# Libraries                                      object
# Public Safety                                  object
# Airport                                        object
# Austin Energy                                  object
# Court                                          object
# Social Services                                object
# Aware of AARC                                  object
# Visit Frequency                                object
# Activities                                     object
# EMS Classes                                    object
# Fire Alarm                                     object
# Public Computer                                object
# Library Internet Acess                         object
# Literature                                     object
# Citizenship Class                              object
# Small Business                                 object
# English Classes                                object
# 9-1-1                                          object
# 3-1-1                                          object
# APD Languages                                  object
# District                                       object
# Housing                                        object
# Housing (Other)                                object
# Status of Ownership                            object
# Status of Ownership (Other)                    object
# Satisfaction With Housing.                     object
# Nursing Home                                   object
# Smoke Detector                                 object
# Recycle                                        object
# Compost                                        object
# Public Transportation                          object
# Bicycling                                      object
# Carpooling                                     object
# Personal Car                                   object
# Car Share                                      object
# Walking                                        object
# Other Transportation                          float64
# Other Transportation Description               object
# Access to a Computer                           object
# Mobile Devices                                 object
# Home Phone                                     object
# Public Meeting                                 object
# Council Meeting                                object
# Contact City Official                          object
# City Election                                  object
# Focus Group                                    object
# Informed                                       object
# City Effort Satisfaction                       object
# Paper (City-based)                             object
# TV/Radio (City-based)                          object
# Website (City-based)                           object
# Social Networks (City-based)                   object
# People (City-based)                            object
# Other (City-based)                             object
# Other Description (City-based)                 object
# Paper (Non-city-based Ethnic)                  object
# TV/Radio (Non-city-based Ethnic)               object
# Website (Non-city-based Ethnic)                object
# Social Networks (Non-city-based Ethnic)        object
# People (Non-city-based Ethnic)                 object
# Other (Non-city-based Ethnic)                  object
# Other Description (Non-city-based Ethnic)      object
# Paper (Non-city-based General)                 object
# TV/Radio (Non-city-based General)              object
# Website (Non-city-based General)               object
# Social Networks (Non-city-based General)       object
# People (Non-city-based General)                object
# Other (Non-city-based General)                 object
# Other Description (Non-city-based General)     object
# Preferred Type                                 object
# Concerns                                       object
# dtype: object

# %%
#Eliminate spaces from each column title
new_columns = [col.replace(' ','_') for col in list(raw_data.columns)]
raw_data.columns = new_columns
list(raw_data.columns)
# Out:
# ['Survey_ID',
#  'Age',
#  'Gender',
#  'Ethnicity',
#  'Marital_Status',
#  'Education_Completed',
#  'Household_Size',
#  'No_One',
#  'Spouse',
#  'Children',
#  'Grand_Children',
#  'Parent',
#  'Grandparent',
#  'Brother/Sister',
#  'Other_Relative',
#  'Friends',
#  'Other_',
#  'Other_Description',
#  'Religion',
#  'Religion_Other',
#  'Full_Time_Employment',
#  'Part_Time_Employment',
#  'Self_Employed_Full_Time',
#  'Self_Employed_Part_Time',
#  'Student',
#  'Homemaker',
#  'Disabled',
#  'Unemployed',
#  'Retired',
#  'Other_Employement',
#  'Other_Employment_Description',
#  'Occupation',
#  'Occupation_Other',
#  'Income',
#  'Achieving_Ends_Meet',
#  'US_Born',
#  'Duration_of_Residency',
#  'Primary_Language',
#  'English_Speaking',
#  'English_Difficulties',
#  'Familiarity_with_America',
#  'Familiarity_with_Ethnic_Origin',
#  'Identify_Ethnically',
#  'Belonging',
#  'Discrimination_',
#  'Present_Health',
#  'Present_Mental_Health',
#  'Present_Oral_Health',
#  'Hygiene_Assistance',
#  'Smoking',
#  'Drinking',
#  'Regular_Exercise',
#  'Healthy_Diet',
#  'Hypertension',
#  'Heart_Disease',
#  'Stroke',
#  'Diabetes',
#  'Cancer',
#  'Arthritis',
#  'Hepatitis',
#  'Kidney_Problem',
#  'Asthma',
#  'COPD',
#  'Physical_Check-up',
#  'Dentist_Check-up',
#  'Urgentcare',
#  'Folkmedicine',
#  'Primary_Care',
#  'Health_Insurance',
#  'Dental_Insurance',
#  'Unmet_Health_Need',
#  'Unmet_Dental_Needs',
#  'Transportation_(Medical)',
#  'Interpretation_(Medical)',
#  'Comunication_Problem',
#  'Preferance',
#  'Language',
#  'users',
#  'Satisfaction',
#  'Family',
#  'Close_Friend',
#  'Acquaintances',
#  'Heal_Professionals',
#  'Mobile_Apps',
#  'Email',
#  'Social_Networks',
#  'Online_Communities',
#  'Health_Website',
#  'Other',
#  'Health_Info_Discription',
#  'Quality_of_Life',
#  'Satisfied_With_Life_1',
#  'Satisfied_With_Life_2',
#  'Psychiatrist',
#  'General_Practitioner',
#  'Therapist/Counselor_',
#  'Religious_Leader',
#  'Weakness',
#  'Shame',
#  'Disappointment',
#  'Disclosure',
#  'Antidepressants',
#  'Danger',
#  'Recovery',
#  'Treatment',
#  'Counseling',
#  'Preference',
#  'Knowledge',
#  'Diagnosed',
#  'Concern_for_Self_(AD)',
#  'Concern_for_Others_(AD)',
#  'Prevention',
#  'Plan_(AD)',
#  'Education_(AD)',
#  'Services_(AD)',
#  'Language_Barrier_(AD)',
#  'Fate_(AD)',
#  'Aging_(AD)',
#  'Embarrassing_(AD)',
#  'Avoidance_(AD)',
#  'Cure_(AD)',
#  'Nursing_Home_(AD)',
#  'Advanced_Directives',
#  'Have_an_Advanced_Directive',
#  'Superstition',
#  'See_Family',
#  'Close_Family',
#  'Helpful_Family',
#  'See_Friends',
#  'Close_Friends',
#  'Helpful_Friends',
#  'Family_Respect',
#  'Similar_Values',
#  'Successful_Family',
#  'Trust',
#  'Loyalty',
#  'Family_Pride',
#  'Expression',
#  'Spend_Time_Together',
#  'Feel_Close_',
#  'Togetherness',
#  'Religious_Attendance',
#  'Religious_Importance',
#  'Close-knit_Community',
#  'Helpful_Community',
#  'Community_Shares_Values',
#  'Get_Along',
#  'Community_Trust',
#  'Residency_',
#  'Place_to_Live',
#  'Raising_Children',
#  'Place_to_Work',
#  'Small_Businesses_',
#  'Place_to_Retire',
#  'Arts_and_Culture',
#  'Safety',
#  'Traffic',
#  'Qualtiy_of_Life',
#  'Quality_of_Service',
#  'Parks_and_Recs',
#  'Libraries',
#  'Public_Safety',
#  'Airport',
#  'Austin_Energy',
#  'Court',
#  'Social_Services',
#  'Aware_of_AARC',
#  'Visit_Frequency_',
#  'Activities',
#  'EMS_Classes',
#  'Fire_Alarm',
#  'Public_Computer',
#  'Library_Internet_Acess',
#  'Literature',
#  'Citizenship_Class',
#  'Small_Business',
#  'English_Classes',
#  '9-1-1',
#  '3-1-1',
#  'APD_Languages_',
#  'District',
#  'Housing_',
#  'Housing_(Other)',
#  'Status_of_Ownership',
#  'Status_of_Ownership_(Other)',
#  'Satisfaction_With_Housing.',
#  'Nursing_Home',
#  'Smoke_Detector',
#  'Recycle',
#  'Compost',
#  'Public_Transportation',
#  'Bicycling',
#  'Carpooling',
#  'Personal_Car',
#  'Car_Share',
#  'Walking',
#  'Other_Transportation',
#  'Other_Transportation_Description',
#  'Access_to_a_Computer',
#  'Mobile_Devices',
#  'Home_Phone',
#  'Public_Meeting',
#  'Council_Meeting',
#  'Contact_City_Official',
#  'City_Election',
#  'Focus_Group',
#  'Informed',
#  'City_Effort_Satisfaction',
#  'Paper_(City-based)',
#  'TV/Radio_(City-based)',
#  'Website_(City-based)',
#  'Social_Networks_(City-based)',
#  'People_(City-based)',
#  'Other_(City-based)',
#  'Other_Description_(City-based)',
#  'Paper_(Non-city-based_Ethnic)',
#  'TV/Radio_(Non-city-based_Ethnic)',
#  'Website_(Non-city-based_Ethnic)',
#  'Social_Networks_(Non-city-based_Ethnic)',
#  'People_(Non-city-based_Ethnic)',
#  'Other_(Non-city-based_Ethnic)',
#  'Other_Description_(Non-city-based_Ethnic)',
#  'Paper_(Non-city-based_General)',
#  'TV/Radio_(Non-city-based_General)',
#  'Website_(Non-city-based_General)',
#  'Social_Networks_(Non-city-based_General)',
#  'People_(Non-city-based_General)',
#  'Other_(Non-city-based_General)',
#  'Other_Description_(Non-city-based_General)',
#  'Preferred_Type',
#  'Concerns']

# %%
raw_data.dtypes
# Out:
# Survey_ID                                       int64
# Age                                           float64
# Gender                                         object
# Ethnicity                                      object
# Marital_Status                                 object
# Education_Completed                           float64
# Household_Size                                float64
# No_One                                         object
# Spouse                                         object
# Children                                       object
# Grand_Children                                 object
# Parent                                         object
# Grandparent                                   float64
# Brother/Sister                                 object
# Other_Relative                                float64
# Friends                                        object
# Other_                                        float64
# Other_Description                              object
# Religion                                       object
# Religion_Other                                 object
# Full_Time_Employment                           object
# Part_Time_Employment                           object
# Self_Employed_Full_Time                       float64
# Self_Employed_Part_Time                       float64
# Student                                        object
# Homemaker                                      object
# Disabled                                      float64
# Unemployed                                    float64
# Retired                                        object
# Other_Employement                             float64
# Other_Employment_Description                   object
# Occupation                                     object
# Occupation_Other                               object
# Income                                         object
# Achieving_Ends_Meet                           float64
# US_Born                                        object
# Duration_of_Residency                         float64
# Primary_Language                              float64
# English_Speaking                               object
# English_Difficulties                           object
# Familiarity_with_America                       object
# Familiarity_with_Ethnic_Origin                 object
# Identify_Ethnically                            object
# Belonging                                      object
# Discrimination_                               float64
# Present_Health                                 object
# Present_Mental_Health                          object
# Present_Oral_Health                            object
# Hygiene_Assistance                            float64
# Smoking                                       float64
# Drinking                                      float64
# Regular_Exercise                              float64
# Healthy_Diet                                  float64
# Hypertension                                   object
# Heart_Disease                                 float64
# Stroke                                        float64
# Diabetes                                       object
# Cancer                                        float64
# Arthritis                                      object
# Hepatitis                                     float64
# Kidney_Problem                                float64
# Asthma                                        float64
# COPD                                          float64
# Physical_Check-up                              object
# Dentist_Check-up                               object
# Urgentcare                                     object
# Folkmedicine                                   object
# Primary_Care                                   object
# Health_Insurance                               object
# Dental_Insurance                               object
# Unmet_Health_Need                              object
# Unmet_Dental_Needs                             object
# Transportation_(Medical)                       object
# Interpretation_(Medical)                       object
# Comunication_Problem                           object
# Preferance                                     object
# Language                                       object
# users                                         float64
# Satisfaction                                   object
# Family                                         object
# Close_Friend                                   object
# Acquaintances                                  object
# Heal_Professionals                             object
# Mobile_Apps                                    object
# Email                                          object
# Social_Networks                                object
# Online_Communities                             object
# Health_Website                                 object
# Other                                         float64
# Health_Info_Discription                        object
# Quality_of_Life                               float64
# Satisfied_With_Life_1                          object
# Satisfied_With_Life_2                          object
# Psychiatrist                                  float64
# General_Practitioner                           object
# Therapist/Counselor_                          float64
# Religious_Leader                               object
# Weakness                                       object
# Shame                                          object
# Disappointment                                 object
# Disclosure                                     object
# Antidepressants                                object
# Danger                                         object
# Recovery                                       object
# Treatment                                      object
# Counseling                                     object
# Preference                                     object
# Knowledge                                      object
# Diagnosed                                      object
# Concern_for_Self_(AD)                          object
# Concern_for_Others_(AD)                        object
# Prevention                                     object
# Plan_(AD)                                      object
# Education_(AD)                                 object
# Services_(AD)                                  object
# Language_Barrier_(AD)                          object
# Fate_(AD)                                      object
# Aging_(AD)                                     object
# Embarrassing_(AD)                              object
# Avoidance_(AD)                                 object
# Cure_(AD)                                      object
# Nursing_Home_(AD)                              object
# Advanced_Directives                            object
# Have_an_Advanced_Directive                     object
# Superstition                                   object
# See_Family                                    float64
# Close_Family                                  float64
# Helpful_Family                                float64
# See_Friends                                   float64
# Close_Friends                                 float64
# Helpful_Friends                               float64
# Family_Respect                                 object
# Similar_Values                                 object
# Successful_Family                              object
# Trust                                          object
# Loyalty                                        object
# Family_Pride                                   object
# Expression                                     object
# Spend_Time_Together                            object
# Feel_Close_                                    object
# Togetherness                                   object
# Religious_Attendance                           object
# Religious_Importance                           object
# Close-knit_Community                           object
# Helpful_Community                              object
# Community_Shares_Values                        object
# Get_Along                                      object
# Community_Trust                                object
# Residency_                                    float64
# Place_to_Live                                  object
# Raising_Children                               object
# Place_to_Work                                  object
# Small_Businesses_                              object
# Place_to_Retire                                object
# Arts_and_Culture                               object
# Safety                                         object
# Traffic                                        object
# Qualtiy_of_Life                                object
# Quality_of_Service                             object
# Parks_and_Recs                                 object
# Libraries                                      object
# Public_Safety                                  object
# Airport                                        object
# Austin_Energy                                  object
# Court                                          object
# Social_Services                                object
# Aware_of_AARC                                  object
# Visit_Frequency_                               object
# Activities                                     object
# EMS_Classes                                    object
# Fire_Alarm                                     object
# Public_Computer                                object
# Library_Internet_Acess                         object
# Literature                                     object
# Citizenship_Class                              object
# Small_Business                                 object
# English_Classes                                object
# 9-1-1                                          object
# 3-1-1                                          object
# APD_Languages_                                 object
# District                                       object
# Housing_                                       object
# Housing_(Other)                                object
# Status_of_Ownership                            object
# Status_of_Ownership_(Other)                    object
# Satisfaction_With_Housing.                     object
# Nursing_Home                                   object
# Smoke_Detector                                 object
# Recycle                                        object
# Compost                                        object
# Public_Transportation                          object
# Bicycling                                      object
# Carpooling                                     object
# Personal_Car                                   object
# Car_Share                                      object
# Walking                                        object
# Other_Transportation                          float64
# Other_Transportation_Description               object
# Access_to_a_Computer                           object
# Mobile_Devices                                 object
# Home_Phone                                     object
# Public_Meeting                                 object
# Council_Meeting                                object
# Contact_City_Official                          object
# City_Election                                  object
# Focus_Group                                    object
# Informed                                       object
# City_Effort_Satisfaction                       object
# Paper_(City-based)                             object
# TV/Radio_(City-based)                          object
# Website_(City-based)                           object
# Social_Networks_(City-based)                   object
# People_(City-based)                            object
# Other_(City-based)                             object
# Other_Description_(City-based)                 object
# Paper_(Non-city-based_Ethnic)                  object
# TV/Radio_(Non-city-based_Ethnic)               object
# Website_(Non-city-based_Ethnic)                object
# Social_Networks_(Non-city-based_Ethnic)        object
# People_(Non-city-based_Ethnic)                 object
# Other_(Non-city-based_Ethnic)                  object
# Other_Description_(Non-city-based_Ethnic)      object
# Paper_(Non-city-based_General)                 object
# TV/Radio_(Non-city-based_General)              object
# Website_(Non-city-based_General)               object
# Social_Networks_(Non-city-based_General)       object
# People_(Non-city-based_General)                object
# Other_(Non-city-based_General)                 object
# Other_Description_(Non-city-based_General)     object
# Preferred_Type                                 object
# Concerns                                       object
# dtype: object

# %%
#Begin correcting typos in column headers
raw_data['Preferance'].rename('Preference')
# Out:
# 0       NaN
# 1       NaN
# 2       Yes
# 3       NaN
# 4       NaN
#        ...
# 2604      0
# 2605      0
# 2606      0
# 2607    Yes
# 2608      0
# Name: Preference, Length: 2609, dtype: object

# %% [markdown]
# ### Step 1: Handling Income Ranges ###
# The step below will reassign income ranges to the minimum income value.

# %%
#Clean up currency values
incomes = [(str(value).replace('$','').replace(',','').split(' - ')[0].split(' ')[0]) for value in raw_data['Income'].values]
raw_data['Income'] = pd.to_numeric(incomes, errors = 'coerce', downcast = 'signed')
raw_data['Income'].rename('Minimum_Income')
# Out:
# 0           NaN
# 1       30000.0
# 2           0.0
# 3           NaN
# 4           NaN
#          ...
# 2604    30000.0
# 2605    60000.0
# 2606    10000.0
# 2607    10000.0
# 2608    70000.0
# Name: Minimum_Income, Length: 2609, dtype: float64

# %% [markdown]
# ### Step 2: Hand-picking Numerical and Droppable Variables ###
# In this type of survey, there are a limited number of numerical data, and most of the data could either be handled as categorical or "scored" quantitative data. The output of the functions below will create 2 dataframes, one in which responses are categorized and the other in which they are converted to a numerical "score"

# %%
#Identify columns that should remain numerical by comparing output of Find_binary_vars() with the original df
numerical_vars = ['Survey_ID','Age','Education_Completed','Household_Size','Quality_of_Life', 'Income', 'Duration_of_Residency']
#Drop columns with a limited number of affirmative responses
data=raw_data.drop(['Cancer','Hepatitis','Kidney_Problem','Asthma','COPD'], axis=1)

# %% [markdown]
# ### Step 3: Function to Identify "Yes/No" or other Binary-Response Question ###

# %%
#The function below aims to identify all "Yes/No" questions, given that some were coded as "Yes/0", "1/0", etc.
import re
def Find_binary_vars(df):
    """
    This function will identify if one of the top 2 responses matches a binary response, then codes the values to '1/0'.
    
    Args:
    df (pd.DataFrame) = the dataframe with binary variables. 
    
    Returns:
    Dataframe with new values for the appropriate columns
    
    """
    global binary_vars 
    binary_vars = set()
    columns = list(df.drop(numerical_vars, axis=1).columns)
    binary_responses = ['Yes','No','0',0,'1',1]
    for col in columns:
        indices_of_counts = df[col].value_counts().index[:2]
        for response in binary_responses:
            if response in indices_of_counts[:2]:
                binary_vars.add(col)
    for var in binary_vars:
        s = df[var].replace('[Nn]o', 0, regex=True).dropna().astype('str')
        s = s.where(s.str.startswith('0'), other=1)
        df[var] = s

# %%
Find_binary_vars(data)
#Check list of columns processed by function above
binary_vars
# Out:
# {'3-1-1',
#  '9-1-1',
#  'APD_Languages_',
#  'Access_to_a_Computer',
#  'Achieving_Ends_Meet',
#  'Acquaintances',
#  'Advanced_Directives',
#  'Aging_(AD)',
#  'Antidepressants',
#  'Arthritis',
#  'Avoidance_(AD)',
#  'Aware_of_AARC',
#  'Bicycling',
#  'Brother/Sister',
#  'Car_Share',
#  'Carpooling',
#  'Children',
#  'Citizenship_Class',
#  'City_Election',
#  'Close_Friend',
#  'Compost',
#  'Comunication_Problem',
#  'Contact_City_Official',
#  'Council_Meeting',
#  'Counseling',
#  'Cure_(AD)',
#  'Danger',
#  'Dental_Insurance',
#  'Dentist_Check-up',
#  'Diabetes',
#  'Diagnosed',
#  'Disabled',
#  'Disappointment',
#  'Disclosure',
#  'Discrimination_',
#  'District',
#  'Drinking',
#  'EMS_Classes',
#  'Education_(AD)',
#  'Email',
#  'Embarrassing_(AD)',
#  'English_Classes',
#  'Family',
#  'Fate_(AD)',
#  'Fire_Alarm',
#  'Focus_Group',
#  'Folkmedicine',
#  'Friends',
#  'Full_Time_Employment',
#  'General_Practitioner',
#  'Grand_Children',
#  'Grandparent',
#  'Have_an_Advanced_Directive',
#  'Heal_Professionals',
#  'Health_Insurance',
#  'Health_Website',
#  'Healthy_Diet',
#  'Heart_Disease',
#  'Home_Phone',
#  'Homemaker',
#  'Hygiene_Assistance',
#  'Hypertension',
#  'Interpretation_(Medical)',
#  'Language_Barrier_(AD)',
#  'Library_Internet_Acess',
#  'Literature',
#  'Mobile_Apps',
#  'Mobile_Devices',
#  'No_One',
#  'Nursing_Home',
#  'Nursing_Home_(AD)',
#  'Online_Communities',
#  'Other',
#  'Other_',
#  'Other_(City-based)',
#  'Other_(Non-city-based_Ethnic)',
#  'Other_(Non-city-based_General)',
#  'Other_Employement',
#  'Other_Relative',
#  'Other_Transportation',
#  'Paper_(City-based)',
#  'Paper_(Non-city-based_Ethnic)',
#  'Paper_(Non-city-based_General)',
#  'Parent',
#  'Part_Time_Employment',
#  'People_(City-based)',
#  'People_(Non-city-based_Ethnic)',
#  'People_(Non-city-based_General)',
#  'Personal_Car',
#  'Physical_Check-up',
#  'Plan_(AD)',
#  'Preferance',
#  'Preference',
#  'Primary_Care',
#  'Primary_Language',
#  'Psychiatrist',
#  'Public_Computer',
#  'Public_Meeting',
#  'Public_Transportation',
#  'Recovery',
#  'Recycle',
#  'Regular_Exercise',
#  'Religious_Leader',
#  'Residency_',
#  'Retired',
#  'Self_Employed_Full_Time',
#  'Self_Employed_Part_Time',
#  'Services_(AD)',
#  'Shame',
#  'Small_Business',
#  'Smoke_Detector',
#  'Smoking',
#  'Social_Networks',
#  'Social_Networks_(City-based)',
#  'Social_Networks_(Non-city-based_Ethnic)',
#  'Social_Networks_(Non-city-based_General)',
#  'Spouse',
#  'Stroke',
#  'Student',
#  'TV/Radio_(City-based)',
#  'TV/Radio_(Non-city-based_Ethnic)',
#  'TV/Radio_(Non-city-based_General)',
#  'Therapist/Counselor_',
#  'Transportation_(Medical)',
#  'Treatment',
#  'US_Born',
#  'Unemployed',
#  'Unmet_Dental_Needs',
#  'Unmet_Health_Need',
#  'Urgentcare',
#  'Walking',
#  'Weakness',
#  'Website_(City-based)',
#  'Website_(Non-city-based_Ethnic)',
#  'Website_(Non-city-based_General)',
#  'users'}

# %% [markdown]
# ### Step 4: Find "Strongly Agree/Disagree" questions, or other questions that imply a ranking or score ###

# %%
def Find_scoring_vars(df):
    """
    This function will identify if responses match the 'responses' dictionary, and score responses accordingly. 
    This function works best if coded responses don't appear in overlapping response, i.e. 'Very good' is part of only 1
    type of response, or if a given response has the same score throughout the dataset, i.e 'Very Good' can always be scored
    the same.
    
    Args:
    df (pd.DataFrame) = the dataframe with binary variables. 
    
    Returns:
    Dataframe with new values for the appropriate columns
    
    """
    global scoring_vars 
    scoring_vars = []
    columns = list(df.columns)
    responses = {
        'Strongly agree': 3,
        'Agree': 2,
        'Slightly agree': 1,
        'Somewhat agree': 1,
        'Neither agree or disagree': 0,
        'Neutral':0,
        'Somewhat disagree': -1,
        'Slightly disagree': -1,
        'Disagree': -2,
        'Strongly disagree': -3,
        'Poor': 0,
        'Fair': 1,
        'Good': 2,
        'Very Good': 3,
        'Excellent': 4,
        'Not at all': 0,
        'Nothing at all': 0,
        'Not much': 1,
        'Not very much': 1,
        'Pretty much': 2,
        'Very much': 3,
        'Never used': np.nan,
        'Very dissatisfied': -2,
        'Not at all satisfied': -1,
        'Somewhat dissatisfied': -1,
        'Not very much satisfied': -1,
        'Niether satisfied or dissatisfied': 0,
        'Somewhat satisfied': 2,
        'Somewhat': 2,
        'Pretty much satisfied': 3,
        'Very satisfied': 4,
        'Very much satisfied': 4,
        'Never': 0,
        'Rarely': 1,
        'Some of the time': 2,
        'Often': 3,
        'Very low': 0,
        'Low': 1,
        'High': 2,
        'Very high': 3,
        'Not very close': 0,
        'Somewhat close': 1,
        'Very close': 2,
        'Not well': 0,
        'Well': 1,
        'Very well': 2,
        'Very important': 3,
        'Somewhat important': 2,
        'Not very important': 1,
        'Not at all important': 0       
    }
    for col in columns:
        s = df[col]
        if s.dtypes == 'object':
            if [i for i in responses.keys() if i in s.values]:
                scoring_vars.append(col)
                s = s.replace(responses)
                df[col] = s

# %%
Find_scoring_vars(data)
scoring_vars
# Out:
# ['English_Speaking',
#  'English_Difficulties',
#  'Familiarity_with_America',
#  'Familiarity_with_Ethnic_Origin',
#  'Identify_Ethnically',
#  'Belonging',
#  'Present_Health',
#  'Present_Mental_Health',
#  'Present_Oral_Health',
#  'Satisfaction',
#  'Satisfied_With_Life_1',
#  'Satisfied_With_Life_2',
#  'Knowledge',
#  'Concern_for_Self_(AD)',
#  'Concern_for_Others_(AD)',
#  'Prevention',
#  'Superstition',
#  'Family_Respect',
#  'Similar_Values',
#  'Successful_Family',
#  'Trust',
#  'Loyalty',
#  'Family_Pride',
#  'Expression',
#  'Spend_Time_Together',
#  'Feel_Close_',
#  'Togetherness',
#  'Religious_Attendance',
#  'Religious_Importance',
#  'Close-knit_Community',
#  'Helpful_Community',
#  'Community_Shares_Values',
#  'Get_Along',
#  'Community_Trust',
#  'Place_to_Live',
#  'Raising_Children',
#  'Place_to_Work',
#  'Small_Businesses_',
#  'Place_to_Retire',
#  'Arts_and_Culture',
#  'Safety',
#  'Traffic',
#  'Qualtiy_of_Life',
#  'Quality_of_Service',
#  'Parks_and_Recs',
#  'Libraries',
#  'Public_Safety',
#  'Airport',
#  'Austin_Energy',
#  'Court',
#  'Social_Services',
#  'Visit_Frequency_',
#  'Activities',
#  'Satisfaction_With_Housing.',
#  'City_Effort_Satisfaction',
#  'Concerns']

# %% [markdown]
# ### Step 6: Identifying Other Categorical Variables ###
# After re-scoring our binary and "score" variables, we can revisit our data for a few final steps
# <ol>
#     <li>Look through column headers for typos and corrections; and</li>
#     <li>identify conventional categorical variables, such as gender, ethnicity, etc.</li>
#     </ol>

# %%
#Remove leading and trailing characters from column headers
new_columns = [col.strip('_') for col in list(data.columns)]
data.columns = new_columns

# %%
original_categories = ['Gender','Ethnicity','Marital_Status','Religion','Language','Religious_Attendance','Housing', 'Informed','Preferred_Type']

# %%
#Create processed data outputs
# %cd ..
# %cd data\processed
data.to_csv('Processed Data.csv')
pd.DataFrame(scoring_vars).to_csv('Scoring variables.csv')
pd.DataFrame(binary_vars).to_csv('Binary variables.csv')
pd.DataFrame(original_categories).to_csv('Categorical variables.csv')
# Out:
# C:\Users\SiddharthaMisra\Documents\Springboard\AAQL_Analysis
# C:\Users\SiddharthaMisra\Documents\Springboard\AAQL_Analysis\data\processed
# C:\Users\SiddharthaMisra\Anaconda3\lib\site-packages\pandas_profiling\describe.py:392: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)

# %% [markdown]
# I kept getting a weird bug with Pandas Profiling when trying to create a profile of my processed data. Here was my workaround:

# %%
#Export processed data profile
data = pd.read_csv('Processed Data.csv')
from pandas_profiling import ProfileReport
report = ProfileReport(data).to_file('Pandas_Processed_Data_Profile.html')
# Out:
# C:\Users\SiddharthaMisra\Anaconda3\lib\site-packages\pandas_profiling\describe.py:392: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
